# %% [markdown]
# ## Installing **Pandas** and Importing the Library

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/162.8 kB 435.7 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/162.8 kB 573.4 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/162.8 kB 595.3 kB/s eta 0:00:01
#      ------------------------------------ 162.8/162.8 kB 696.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.0 MB 2.2 MB/s eta 0:00:04
#     --------------------------------------- 0.2/8.0 MB 2.4 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/8.0 MB 2.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/8.0 MB 2.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/8.0 MB 2.0 MB/s eta 0:00:04
# ...

# %% [markdown]
# Import the Library package

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Series and DataFrame

# %%
data = [10, 20, 30, 40]
series = pd.Series(data)
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# # Data selection and indexing

# %%
data = [10, 20, 30, 40]
cus_index = ["A", "B", "C", "D"]
series_new = pd.Series(data, index=cus_index)
series_new
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64

# %% [markdown]
# Access the indesx values

# %%
print(series[3])
print(cus_index[2])
# Out:
# 40
# C

# %%
result = series + 10
result
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# dtype: int64

# %% [markdown]
# ## Data Frames

# %% [markdown]
# A DataFrame is a **two-dimensional, size-mutable, and potentially heterogeneous tabular** data structure with labeled axes (rows and columns).<br>
# It's similar to a table in a database or an Excel spreadsheet.<br><br>
#
# ## Key Features of DataFrames:
# **Labeled Axes:** Both rows and columns have labels, which makes data manipulation and retrieval easy.<br>
# **Heterogeneous Data:** Columns can contain different types of data (integers, floats, strings, etc.).<br>
# **Size-Mutable:** We can add or delete columns and rows.

# %%
data = {
    'Name' : ['Kamal', 'Vimal', 'Jhon', 'Stephen'],
    'Age' : [10, 25, 45, 12],
    'City' : ['NY', 'CLMB', 'TN', 'UK']
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age  City
# 0    Kamal   10    NY
# 1    Vimal   25  CLMB
# 2     Jhon   45    TN
# 3  Stephen   12    UK

# %% [markdown]
# ## Data Selections

# %%
print(df['Name'])
print()
print(df['Age'])
# Out:
# 0      Kamal
# 1      Vimal
# 2       Jhon
# 3    Stephen
# Name: Name, dtype: object
#
# 0    10
# 1    25
# 2    45
# 3    12
# Name: Age, dtype: int64

# %%
df.loc[0]
# Out:
# Name    Kamal
# Age        10
# City       NY
# Name: 0, dtype: object

# %% [markdown]
# # Loading Data from a CSV file

# %%
df = pd.read_csv('../Deep Learning for Computer Vision Tutorial/Datasets/Sample.csv')
df
# Out:
#       Username First Name  Last Name                 Email     Phone  Age
# 0       jsmith       John      Smith      jsmith@email.com  555-1234   20
# 1       mjones       Mary      Jones      mjones@email.com  555-5678   63
# 2       abrown      Alice      Brown      abrown@email.com  555-9012   87
# ..         ...        ...        ...                   ...       ...  ...
# 7      lthomas      Laura     Thomas     lthomas@email.com  555-8023   12
# 8   mrodriguez    Michael  Rodriguez  mrodriguez@email.com       NaN   46
# 9     kcollins      Kelly    Collins    kcollins@email.com  555-6432   23
#
# [10 rows x 6 columns]

# %% [markdown]
# # Data cleaning and Preprocessing

# %%
df.head()
# Out:
#     Username First Name Last Name                Email     Phone  Age
# 0     jsmith       John     Smith     jsmith@email.com  555-1234   20
# 1     mjones       Mary     Jones     mjones@email.com  555-5678   63
# 2     abrown      Alice     Brown     abrown@email.com  555-9012   87
# 3   tjohnson        Tom   Johnson   tjohnson@email.com  555-3456   45
# 4  swilliams      Sarah  Williams  swilliams@email.com  555-7890   26

# %% [markdown]
# Limit the dataset shows

# %%
pd.options.display.max_rows = 6
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    10 non-null     object
#  1   First Name  10 non-null     object
#  2   Last Name   10 non-null     object
#  3   Email       10 non-null     object
#  4   Phone       9 non-null      object
#  5   Age         10 non-null     int64
# dtypes: int64(1), object(5)
# memory usage: 612.0+ bytes

# %% [markdown]
# Give some information about the array

# %%
df.describe()
# Out:
#              Age
# count  10.000000
# mean   40.700000
# std    24.495124
# ...          ...
# 50%    35.500000
# 75%    58.750000
# max    87.000000
#
# [8 rows x 1 columns]

# %% [markdown]
# Shape of the array

# %%
df.shape
# Out:
# (10, 6)

# %% [markdown]
# Check the **NULL** values

# %%
df.isna()
# Out:
#     Username  First Name  Last Name  Email  Phone    Age
# 0      False       False      False  False  False  False
# 1      False       False      False  False  False  False
# 2      False       False      False  False  False  False
# ..       ...         ...        ...    ...    ...    ...
# 7      False       False      False  False  False  False
# 8      False       False      False  False   True  False
# 9      False       False      False  False  False  False
#
# [10 rows x 6 columns]

# %% [markdown]
# Summation of the **NULL** values

# %%
df.isna().sum()
# Out:
# Username      0
# First Name    0
# Last Name     0
# Email         0
# Phone         1
# Age           0
# dtype: int64

# %% [markdown]
# Clean(drop) the **NULL** rows

# %%
df.dropna()
# Out:
#      Username First Name Last Name                Email     Phone  Age
# 0      jsmith       John     Smith     jsmith@email.com  555-1234   20
# 1      mjones       Mary     Jones     mjones@email.com  555-5678   63
# 2      abrown      Alice     Brown     abrown@email.com  555-9012   87
# ..        ...        ...       ...                  ...       ...  ...
# 6   danderson      David  Anderson  danderson@email.com  555-1357   21
# 7     lthomas      Laura    Thomas    lthomas@email.com  555-8023   12
# 9    kcollins      Kelly   Collins   kcollins@email.com  555-6432   23
#
# [9 rows x 6 columns]

# %% [markdown]
# Fill the NULL values with random values

# %%
df.fillna(555-1434, inplace=True)
df
# Out:
#       Username First Name  Last Name                 Email     Phone  Age
# 0       jsmith       John      Smith      jsmith@email.com  555-1234   20
# 1       mjones       Mary      Jones      mjones@email.com  555-5678   63
# 2       abrown      Alice      Brown      abrown@email.com  555-9012   87
# ..         ...        ...        ...                   ...       ...  ...
# 7      lthomas      Laura     Thomas     lthomas@email.com  555-8023   12
# 8   mrodriguez    Michael  Rodriguez  mrodriguez@email.com      -879   46
# 9     kcollins      Kelly    Collins    kcollins@email.com  555-6432   23
#
# [10 rows x 6 columns]

# %%
df["Phone"].fillna(555-4679, inplace=True)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13612\2548833634.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Phone"].fillna(555-4679, inplace=True)
#       Username First Name  Last Name                 Email     Phone  Age
# 0       jsmith       John      Smith      jsmith@email.com  555-1234   20
# 1       mjones       Mary      Jones      mjones@email.com  555-5678   63
# 2       abrown      Alice      Brown      abrown@email.com  555-9012   87
# ...

# %% [markdown]
# ## Mean and Mode

# %%
mn = df['Age'].mean()
print("Mean :", mn)

md = df['Age'].mode()
print("Mode :", md)
# Out:
# Mean : 40.7
# Mode : 0    12
# 1    20
# 2    21
#      ..
# 7    63
# 8    64
# 9    87
# Name: Age, Length: 10, dtype: int64

# %% [markdown]
# Clean(drop) the dupicate datas

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       Username First Name  Last Name                 Email     Phone  Age
# 0       jsmith       John      Smith      jsmith@email.com  555-1234   20
# 1       mjones       Mary      Jones      mjones@email.com  555-5678   63
# 2       abrown      Alice      Brown      abrown@email.com  555-9012   87
# ..         ...        ...        ...                   ...       ...  ...
# 7      lthomas      Laura     Thomas     lthomas@email.com  555-8023   12
# 8   mrodriguez    Michael  Rodriguez  mrodriguez@email.com      -879   46
# 9     kcollins      Kelly    Collins    kcollins@email.com  555-6432   23
#
# [10 rows x 6 columns]

# %% [markdown]
# Rename the column name by using pandas

# %%
df.rename(columns= {'Username' : 'Name'}, inplace=True)
df
# Out:
#           Name First Name  Last Name                 Email     Phone  Age
# 0       jsmith       John      Smith      jsmith@email.com  555-1234   20
# 1       mjones       Mary      Jones      mjones@email.com  555-5678   63
# 2       abrown      Alice      Brown      abrown@email.com  555-9012   87
# ..         ...        ...        ...                   ...       ...  ...
# 7      lthomas      Laura     Thomas     lthomas@email.com  555-8023   12
# 8   mrodriguez    Michael  Rodriguez  mrodriguez@email.com      -879   46
# 9     kcollins      Kelly    Collins    kcollins@email.com  555-6432   23
#
# [10 rows x 6 columns]

# %% [markdown]
# # Data Manipulations

# %% [markdown]
# Create a new column

# %%
df["Gender"] = [
    "Male",
    "Female",
    "Male",
    "Female",
    "Male",
    "Female",
    "Male",
    "Male",
    "Male",
    "Female",
]
df
# Out:
#           Name First Name  Last Name                 Email     Phone  Age  \
# 0       jsmith       John      Smith      jsmith@email.com  555-1234   20
# 1       mjones       Mary      Jones      mjones@email.com  555-5678   63
# 2       abrown      Alice      Brown      abrown@email.com  555-9012   87
# ..         ...        ...        ...                   ...       ...  ...
# 7      lthomas      Laura     Thomas     lthomas@email.com  555-8023   12
# 8   mrodriguez    Michael  Rodriguez  mrodriguez@email.com      -879   46
# 9     kcollins      Kelly    Collins    kcollins@email.com  555-6432   23
#
#     Gender
# 0     Male
# 1   Female
# 2     Male
# ..     ...
# 7     Male
# 8     Male
# 9   Female
#
# [10 rows x 7 columns]

# %% [markdown]
# Set the groups

# %%
group_df = df.groupby('Gender')['Age'].mean()
group_df
# Out:
# Gender
# Female    48.750000
# Male      35.333333
# Name: Age, dtype: float64

# %% [markdown]
# ## Corelations

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df.corr()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %% [markdown]
# ## Data Visulaitations

# %%
df.plot(kind='bar', x='Gender', y='Age')
# Out:
# <Axes: xlabel='Gender'>

# %%
df.plot(kind="line", x="Gender", y="Age")
# Out:
# <Axes: xlabel='Gender'>

# %%
df.plot(kind="pie", x="Gender", y="Age")
# Out:
# <Axes: ylabel='Age'>

# %%
df.plot(kind="box", x="Gender", y="Age")
# Out:
# <Axes: >

# %%
df.plot(kind="scatter", x="Gender", y="Age")
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
df.plot(kind="hist", x="Gender", y="Age")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Formal Method

# %%
df.plot(kind='scatter', x='Gender', y='Age', color='red')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Scatter Plot')
plt.show()
